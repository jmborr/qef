# %% [markdown]
# ## Using LMFIT for Sequential and Global Fit of a Water Sample
#
# ### Useful links
# - [lmfit documentation](https://lmfit.github.io/lmfit-py/index.html)
# - [qef documentation](http://qef.readthedocs.io/en/latest/)
# - [matplotlib](https://matplotlib.org) plotting with python
# - [Post your questions](https://gitter.im/basisdoc/Lobby)
#
# <a id='Table of Contents'></a><h3>Table of Contents</h3>
# - <a href='#load_data'>Load data and visualize data</a>
# - <a href='#def_fit_range'>Define the Fitting Range</a>
# - <a href='#def_mod'>Define the model</a>
# - <a href='#init_guess'>Obtain an initial guess</a>
# - <a href='#carry_fit_results'>Carry out the fit and look at results</a>
# - <a href='#seq_fit'>Sequential Fit</a>
# - <a href='#qdep_par'>Q-dependence of some parameters</a>
# - <a href='#init_guess_teix'>Initial Guess for Teixeira Water model</a>
# - <a href='#sim_fit_model'>Model for Simultaneous Fit of All Spectra with Teixeira Water Model</a>

# %% [markdown]
# ### For debugging only

# %%
import sys
from os.path import join as pjn
qef_dir = '/SNS/users/jbq/repositories/qef'
sys.path.append(qef_dir)
data_dir = pjn(qef_dir, 'tests', 'data', 'io')

# %% [markdown]
# ### Imports for fitting

# %%
from __future__ import (absolute_import, division, print_function)

import os
from os.path import join as pjn
import sys
import functools
import lmfit
from lmfit.models import LinearModel, LorentzianModel, ConstantModel, LinearModel

from qef.io.loaders import load_nexus
from qef.models.deltadirac import DeltaDiracModel
from qef.models.tabulatedmodel import TabulatedModel
from qef.models.resolution import TabulatedResolutionModel
from qef.models.teixeira import TeixeiraWaterModel
from qef.operators.convolve import Convolve
# Out:
# /SNS/users/jbq/conda/miniconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from IPython.core.display import HTML
from IPython.core.display import display
from ipywidgets import widgets

import numpy as np

import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# ### Imports for plotting and widgets

# %% [markdown]
# (<a href='#Table of Contents'>Top</a>)<a id='load_data'></a><h3>Load data and visualize data</h3>

# %%
res = load_nexus(pjn(data_dir,'irs26173_graphite_res.nxs'))
emin, emax = np.min(res['x']), np.max(res['x'])
dat = load_nexus(pjn(data_dir,'irs26176_graphite002_red.nxs')) # data has 10 histograms
emin, emax = min(emin, np.min(dat['x'])), max(emax, np.max(dat['x']))
print('resolution range is ({:.4f}, {:.4f})'.format(res['x'][0], res['x'][-1]))
print('data range is ({:.4f}, {:.4f})'.format(dat['x'][0], dat['x'][-1]))
qs = (0.525312757876, 0.7291668809127, 0.9233951329944, 1.105593679447, 1.273206832528, 1.42416584459, 1.556455009584, 1.668282739099, 1.758225254224, 1.825094271503)
# Plot
f, (ax1, ax2) = plt.subplots(1, 2)
ax1.semilogy(res['x'], res['y'][0]); ax1.set_title('resolution')
[ax2.semilogy(dat['x'], data) for data in dat['y']]; ax1.set_title('sample')
# Out:
# WARNING:root:Units of vertical axis is not MomentumTransfer
# WARNING:root:Units of vertical axis is not MomentumTransfer
# resolution range is (-0.1990, 0.1990)
# data range is (-0.5474, 0.5437)
# <img src="data:image/png;base64,..." width="639.9833562209217">
# Text(0.5,1,'sample')

# %% [markdown]
# (<a href='#Table of Contents'>Top</a>)<a id='def_fit_range'></a><h3>Define the Fitting Range</h3>

# %%
e_min = -0.4 ; e_max = 0.4

# Find indexes of dat['x'] with values in (e_min, e_max)
mask = np.intersect1d(np.where(dat['x']>e_min), np.where(dat['x']<e_max))

# Drop data outside the fitting range
fr = dict()  # fitting range. Use in place of 'dat'
fr['x'] = dat['x'][mask]
fr['y'] = np.asarray([y[mask] for y in dat['y']])
fr['e'] = np.asarray([e[mask] for e in dat['e']])

# Plot
f, ax = plt.subplots()
[ax.semilogy(fr['x'], data) for data in fr['y']]; ax.set_title('sample')
# Out:
# <img src="data:image/png;base64,..." width="639.9833562209217">
# Text(0.5,1,'sample')

# %% [markdown]
# (<a href='#Table of Contents'>Top</a>)<a id='def_mod'></a><h3>Define the model</h3>
#
# <center>$S(E) = I \cdot R(Q,E) \otimes \big( eisf \cdot \delta(E-E_0) + (1-eisf) \cdot L(E-E_0) \big) + LB$</center>
#
# We will use the following component models:
# - ConstantModel represents one number that can be fitted
# - DeltaDiracModel
# - LorentzianModel has parameter $sigma \equiv HWHM$
# - TabulatedResolutionModel to store the table of numbers representing the resolution
# - LinearModel for the linear background

# %%
# Create the Model. We put everything under a function which we'll later reuse

def generate_model_and_params(spectrum_index=None):
    r"""Produce an LMFIT model and related set of fitting parameters"""

    sp = '' if spectrum_index is None else '{}_'.format(spectrum_index)  # prefix if spectrum_index passed

    # Model components
    intensity = ConstantModel(prefix='I_'+sp)  # I_amplitude
    elastic = DeltaDiracModel(prefix='e_'+sp)  # e_amplitude, e_center
    inelastic = LorentzianModel(prefix='l_'+sp)  # l_amplitude, l_center, l_sigma (also l_fwhm, l_height)
    resolution = TabulatedResolutionModel(res['x'], res['y'], prefix='r_'+sp)  # (fixed r_amplitude, r_center)
    background = LinearModel(prefix='b_'+sp)  # b_slope, b_intercept

    # Putting it all together
    model = intensity * Convolve(resolution, elastic + inelastic) + background
    parameters = model.make_params()  # model parameters are a separate entity.

    # Ties and constraints
    parameters['e_'+sp+'amplitude'].set(min=0.0, max=1.0)
    parameters['l_'+sp+'center'].set(expr='e_'+sp+'center')  # centers tied
    parameters['l_'+sp+'amplitude'].set(expr='1 - e_'+sp+'amplitude')

    # Some initial sensible values
    init_vals = {'I_'+sp+'c': 1.0, 'e_'+sp+'amplitude': 0.5, 'l_'+sp+'sigma': 0.01,
                 'b_'+sp+'slope': 0, 'b_'+sp+'intercept': 0}
    for p, v in init_vals.items():
        parameters[p].set(value=v)

    return model, parameters

# Call the function
model, params = generate_model_and_params()

# %% [markdown]
# (<a href='#Table of Contents'>Top</a>)<a id='init_guess'></a><h3>Obtain an initial guess</h3>
#
# A widget that compares the evaluation of the model with one of the experimental spectra. You can tweak only the free (unconstrained) parameters.

# %%
# Variables from previous cells and setting of other variables
# params
# e_vals
# model
free_params = [p for p in params.values() if not p.expr and p.vary]  # only adjust free parameters
e_vals = fr['x']
y_exp = fr['y'][0] # associated experimental values for the first histogram
e_exp = fr['e'][0]

f, (ax1, ax2) = plt.subplots(2, 1)
def plot_new_spectrum(an_axis):
    global y_exp
    an_axis.clear()
    an_axis.plot(e_vals, y_exp, color='black', marker='o',
                 markersize=1.0, linewidth=0, label='experiment')
    an_axis.legend()

def plot_guess(an_axis, model_evaluation):
    plot_new_spectrum(an_axis)
    an_axis.plot(e_vals, model_evaluation, color='blue', label='model')
    an_axis.legend()

def plot_difference(an_axis, model_evaluation):
    global y_exp
    an_axis.clear()
    an_axis.plot(e_vals, y_exp - model_evaluation, color='black',
                 markersize=1.0, label='exp - model')
    an_axis.legend()

def i_histogram_changed(bunch):
    global y_exp
    y_exp = fr['y'][bunch['new']]
    global e_exp
    e_exp = fr['e'][bunch['new']]
    plot_new_spectrum(ax1)
    ax2.clear()

# Widget for the spectrum index
w_label = widgets.Label('spectrum index', layout=widgets.Layout(width='10%'))
w_int_text = widgets.BoundedIntText(value=0, min=0, max=len(dat['y']),
                                    layout=widgets.Layout(width='20%'))
w_int_text.observe(i_histogram_changed, 'value')
p_hbox_l = [widgets.HBox([w_label, w_int_text])]

def update_model(name, value, parameters):
    parameters[name].set(value=value)
    return model.eval(x=e_vals, params=parameters)

widget_to_parameter = dict()
def parameter_changed(bunch):
    w_float_text = bunch['owner']
    p_name = widget_to_parameter[w_float_text]
    value = bunch['new']
    w_float_text.step = 0.1 * value  # update the step as 10% of current value
    model_evaluation = update_model(p_name, value, params)
    plot_guess(ax1, model_evaluation)
    plot_difference(ax2, model_evaluation)
    
def p_hbox(p):
    """Generate an HBox widget for a given fitting parameter

    Parameters
    ----------
    p : lmfit parameter
    """
    w_label = widgets.Label(p.name, layout=widgets.Layout(width='10%'))
    w_float_text = widgets.FloatText(value=p.value, layout=widgets.Layout(width='20%'))
    w_float_text.step = 0.1 * p.value
    w_float_text.observe(parameter_changed, 'value')
    widget_to_parameter[w_float_text] = p.name
    return widgets.HBox([w_label, w_float_text])

p_hbox_l.extend([p_hbox(p) for p in free_params])

vertical_layout = widgets.VBox(p_hbox_l)
display(vertical_layout)
# Out:
# <img src="data:image/png;base64,..." width="639.9833562209217">
# VkJveChjaGlsZHJlbj0oSEJveChjaGlsZHJlbj0oTGFiZWwodmFsdWU9dSdzcGVjdHJ1bSBpbmRleCcsIGxheW91dD1MYXlvdXQod2lkdGg9dScxMCUnKSksIEJvdW5kZWRJbnRUZXh0KHZhbHXigKY=

# %% [markdown]
# (<a href='#Table of Contents'>Top</a>)<a id='carry_fit_results'></a><h3>Carry out the fit and look at results</h3>

# %%
fit = model.fit(y_exp, x=e_vals, params=params, weights = 1.0 / e_exp)
print('Chi-square =', fit.redchi)
fit.plot()
print('\n'.join('{} = {}'.format(p.name, p.value) for p in fit.params.values()))
# Out:
# Chi-square = 1.7226521192291908
# <img src="data:image/png;base64,..." width="639.9833562209217">
# I_c = 4.3498490543
# r_amplitude = 1.0
# r_center = 0.0
# e_center = -0.000982554135505
# e_amplitude = 0.0728546275807
# l_sigma = 0.0285712259742
# l_center = -0.000982554135505
# l_amplitude = 0.927145372419
# b_slope = 0.0086709006484
# b_intercept = 0.0218125452455
# l_fwhm = 0.0571424519483
# l_height = 10.3292575211

# %% [markdown]
# (<a href='#Table of Contents'>Top</a>)<a id='seq_fit'></a><h3>Sequential Fit</h3>
#
# Starting from the first spectrum, we iteratively fit spectra of higher q's.
#
# *Special instructions:* If the previous guess was not for the first spectrum, the code will not run but raise and error. Go back to the previous cell and carry out a guess for the first spectrum, then come back here.
#
# We do not assume any particular Q-dependence for the width of the Lorentzian function.

# %%
# Get current spectrum index from the value in the spectrum index widget
spectrum_index = w_int_text.value
if spectrum_index != 0:
    raise RuntimeError('For sequential fit, start with initial guess for first spectrum')

n_spectra = len(fr['y'])
fits = [None,] * n_spectra  # store fits for all the tried spectra
fits[0] = fit # store previous fit

# Iterate over spectra above the currently considered spectrum
for i in range(1 + spectrum_index, n_spectra):
    y_exp = fr['y'][i]
    e_exp = fr['e'][i]
    fit = model.fit(y_exp, x=e_vals, params=params, weights = 1.0 / e_exp)             
    fits[i] = fit  # store fit results

# Show Chi-square versus Q
chi2s = [fit.redchi for fit in fits]
f, ax = plt.subplots()
ax.plot(qs, [fit.redchi for fit in fits])
ax.set_xlabel('Q')
ax.set_ylabel('Chi-squared')
# Out:
# <img src="data:image/png;base64,..." width="639.9833562209217">
# Text(0,0.5,'Chi-squared')

# %% [markdown]
# (<a href='#Table of Contents'>Top</a>)<a id='qdep_par'></a><h3>Q-dependence of some parameters</h3>
#
# The sample is liquid water, thus we expect $EISF \ll 1$

# %%
names = ('l_fwhm', 'e_amplitude')  # fitting parameters we want to plot
ylabels = ('FWHM', 'EISF')  # labels on the Y-axis of the plots
xlabels = ('Q^2', 'Q')  # labels on the X-axis of the plots

q_vals = np.asarray(qs)
xs = (q_vals * q_vals, q_vals)  # we want to plot FWHM versus Q^2 and EISF versus Q

f, axs = plt.subplots(1, len(names))  # as many plots as fitting parameters of interest
for i in range(len(names)):
    name = names[i]  # name of the fit parameter
    y = [fit.params[name].value for fit in fits]
    ax = axs[i]  # select appropriate plotting area
    ax.plot(xs[i], y, marker='o', linestyle='dashed')
    ax.set_xlabel(xlabels[i])
    ax.set_ylabel(ylabels[i])

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="639.9833562209217">

# %% [markdown]
# (<a href='#Table of Contents'>Top</a>)<a id='init_guess_teix'></a><h3>Initial Guess for Teixeira Water model</h3>
#
# We use the previous $FWHM$ to fit $HWHM(Q^2)$ to Teixeira's water model to obtain initial diffusion $D$ and relaxation time coefficients $\tau$
#
# <center>$HWHM = \frac{\hbar D\cdot Q^2}{1 + D \cdot Q^2 \cdot \tau}$ </center>
#
# If $Q$ in Angstroms, $HHWM$ in $meV$, and $\hbar$ in $meV \cdot ps$, then units of $D$ are $A^2/ps$ and units of $\tau$ are $ps$.

# %%
# Collect FHWM from the fits, and associated error in estimation of these optimal values.
hwhms = 0.5 * np.asarray([fit.params['l_fwhm'].value for fit in fits])  # HWHM values


# Create the model
from qef.constants import hbar  # units of meV x ps  or ueV x ns
from lmfit.model import Model

def teixeira(q2s, diff, tau):
    r"""Calculate HWHM for a given Q, diffusion coefficient, and relaxation time

    Parameters
    ----------
    q2s : float
        Q^2 values
    diff : float
        Diffusion coefficient parameter
    tau : float
        Relaxation time parameter

    Returns
    -------
    numpy.ndarray
        HWHM values
    """
    dq2 = diff * q2s
    return hbar * dq2 / (1 + dq2 * tau)

teixeira_model = Model(teixeira)  # create LMFIT Model instance
teixeira_model.set_param_hint('diff', min=0)  # diffusion coefficient must be positive
teixeira_model.set_param_hint('tau', min=0)  # relaxation coefficient must be positive


# Carry out the fit

teixeira_params = teixeira_model.make_params(diff=1.0, tau=1.0)  # initial guess
teixeira_fit = teixeira_model.fit(hwhms, q2s=np.square(q_vals), params=teixeira_params)

# Visualize fit results
o_p = teixeira_fit.params  # optimal parameters
fmt = 'Chi-square = {}\nD = {} A^2/ps\ntau = {} ps'
print(fmt.format(teixeira_fit.redchi, o_p['diff'].value, o_p['tau'].value))
teixeira_fit.plot(xlabel='Q^2', ylabel='HWHM')
# Out:
# Chi-square = 1.04197800631e-05
# D = 0.157246645348 A^2/ps
# tau = 1.16378500352 ps
# <img src="data:image/png;base64,..." width="639.9833562209217">
# (<Figure size 640x640 with 2 Axes>,
#  <matplotlib.gridspec.GridSpec at 0x7f93b96cb350>)

# %% [markdown]
# (<a href='#Table of Contents'>Top</a>)<a id='sim_fit_model'></a><h3>Model for Simultaneous Fit of All Spectra with Teixeira Water Model</h3>
#
# We impose a Q-dependende for the FWHM of the Lorentzian, given by the Teixeira water model. Parameters $D$ and $\tau$ are the only parameters that are same for all spectra.
#
# <center>
# $S(Q, E) = I \cdot R(Q,E) \otimes \big( eisf \cdot \delta(Q, E-E_0) + (1-eisf) \cdot L(Q, E-E_0, FWHM = \frac{2 \hbar D\cdot Q^2}{1 + D \cdot Q^2 \cdot \tau}) \big) + LB$
# </center>
#
# We use $D$ and $\tau$ of the previous fit as initial guesses. We use the sequential fits we did before to initialize all other parameters.

# %%
# Create a model for each spectrum

#initialize models and parameter sets for each spectrum


# create one model for each spectrum, but collect all parameters under
# a single instance of the Parameters class.
l_model = list()
g_params = lmfit.Parameters()
for i in range(n_spectra):
    m, ps = generate_model_and_params(spectrum_index=i)  # model and parameters for one of the spectra
    l_model.append(m)
    [g_params.add(p) for p in ps.values()]

# Initialize parameter set with the optimized parameters from the sequential fit
for i in range(1, n_spectra):
    optimized_params = fits[i].params  # these are I_c, e_amplitude,...
    for name in optimized_params:
        prefix, base = name.split('_')  # for instance, 'e_amplitude' splitted into 'e', and 'amplitude'
        i_name = prefix + '_{}_'.format(i) + base  # i_name is 'e_3_amplitude' for i=3
        g_params[i_name].set(value=optimized_params[name].value)

# Introduce global parameters diff and tau. Use previous optimized values as initial guess
g_params.add('diff', value=o_p['diff'].value, min=0)
g_params.add('tau', value=o_p['tau'].value, min=0)

# Tie each lorentzian l_i_sigma to the teixeira expression
for i in range(n_spectra):
    q2 = q_vals[i] * q_vals[i]
    teixeira_expression = '{hbar}*diff*{q2}/(1+diff*{q2}*tau)'
    g_params['l_{}_sigma'.format(i)].set(expr=teixeira_expression.format(hbar=hbar, q2=q2))

print('Number of varying parameters =',len([p for p in g_params.values() if p.vary]),'!')
g_params.pretty_print()
# Out:
# Number of varying parameters = 52 !
# Name              Value      Min      Max   Stderr     Vary     Expr Brute_Step
# I_0_c                 1     -inf      inf     None     True     None     None
# I_1_c             4.106     -inf      inf     None     True     None     None
# I_2_c              3.84     -inf      inf     None     True     None     None
# I_3_c             3.598     -inf      inf     None     True     None     None
# I_4_c             3.385     -inf      inf     None     True     None     None
# I_5_c             3.231     -inf      inf     None     True     None     None
# I_6_c             3.277     -inf      inf     None     True     None     None
# I_7_c             3.134     -inf      inf     None     True     None     None
# I_8_c             3.071     -inf      inf     None     True     None     None
# I_9_c             2.895     -inf      inf     None     True     None     None
# b_0_intercept         0     -inf      inf     None     True     None     None
# b_0_slope             0     -inf      inf     None     True     None     None
# b_1_intercept    0.0218     -inf      inf     None     True     None     None
# b_1_slope       0.01188     -inf      inf     None     True     None     None
# b_2_intercept   0.02037     -inf      inf     None     True     None     None
# b_2_slope       0.01354     -inf      inf     None     True     None     None
# b_3_intercept   0.01985     -inf      inf     None     True     None     None
# b_3_slope       0.01296     -inf      inf     None     True     None     None
# b_4_intercept   0.02101     -inf      inf     None     True     None     None
# b_4_slope       0.01453     -inf      inf     None     True     None     None
# b_5_intercept   0.02229     -inf      inf     None     True     None     None
# b_5_slope       0.01422     -inf      inf     None     True     None     None
# b_6_intercept   0.02194     -inf      inf     None     True     None     None
# b_6_slope       0.01267     -inf      inf     None     True     None     None
# b_7_intercept   0.02293     -inf      inf     None     True     None     None
# b_7_slope       0.01279     -inf      inf     None     True     None     None
# b_8_intercept   0.02334     -inf      inf     None     True     None     None
# b_8_slope       0.01027     -inf      inf     None     True     None     None
# b_9_intercept   0.03132     -inf      inf     None     True     None     None
# b_9_slope        0.0134     -inf      inf     None     True     None     None
# diff             0.1572        0      inf     None     True     None     None
# e_0_amplitude       0.5        0        1     None     True     None     None
# e_0_center            0     -inf      inf     None     True     None     None
# e_1_amplitude   0.03696        0        1     None     True     None     None
# e_1_center     -0.0005365     -inf      inf     None     True     None     None
# e_2_amplitude   0.02625        0        1     None     True     None     None
# e_2_center     -7.794e-06     -inf      inf     None     True     None     None
# e_3_amplitude   0.02524        0        1     None     True     None     None
# e_3_center     6.647e-06     -inf      inf     None     True     None     None
# e_4_amplitude   0.02443        0        1     None     True     None     None
# e_4_center     -0.0005717     -inf      inf     None     True     None     None
# e_5_amplitude   0.02393        0        1     None     True     None     None
# e_5_center     -0.001786     -inf      inf     None     True     None     None
# e_6_amplitude   0.02489        0        1     None     True     None     None
# e_6_center     -0.002642     -inf      inf     None     True     None     None
# e_7_amplitude   0.02441        0        1     None     True     None     None
# e_7_center     -0.002338     -inf      inf     None     True     None     None
# e_8_amplitude   0.02694        0        1     None     True     None     None
# e_8_center     -0.001824     -inf      inf     None     True     None     None
# e_9_amplitude   0.02598        0        1     None     True     None     None
# e_9_center     -0.004211     -inf      inf     None     True     None     None
# l_0_amplitude       0.5     -inf      inf     None    False 1 - e_0_amplitude     None
# l_0_center            0     -inf      inf     None    False e_0_center     None
# l_0_fwhm           0.02     -inf      inf     None    False 2.0000000*l_0_sigma     None
# l_0_height        15.92     -inf      inf     None    False 0.3183099*l_0_amplitude/max(1.e-15, l_0_sigma)     None
# l_0_sigma       0.02719        0      inf     None    False 0.658211951447*diff*0.275953493587/(1+diff*0.275953493587*tau)     None
# l_1_amplitude     0.963     -inf      inf     None    False     None     None
# l_1_center     -0.0005365     -inf      inf     None    False     None     None
# l_1_fwhm        0.09996     -inf      inf     None    False     None     None
# l_1_height        6.133     -inf      inf     None    False     None     None
# l_1_sigma       0.05015        0      inf     None    False 0.658211951447*diff*0.53168434022/(1+diff*0.53168434022*tau)     None
# l_2_amplitude    0.9738     -inf      inf     None    False     None     None
# l_2_center     -7.794e-06     -inf      inf     None    False     None     None
# l_2_fwhm         0.1507     -inf      inf     None    False     None     None
# l_2_height        4.114     -inf      inf     None    False     None     None
# l_2_sigma       0.07634        0      inf     None    False 0.658211951447*diff*0.852658571638/(1+diff*0.852658571638*tau)     None
# l_3_amplitude    0.9748     -inf      inf     None    False     None     None
# l_3_center     6.647e-06     -inf      inf     None    False     None     None
# l_3_fwhm          0.205     -inf      inf     None    False     None     None
# l_3_height        3.027     -inf      inf     None    False     None     None
# l_3_sigma        0.1034        0      inf     None    False 0.658211951447*diff*1.22233738403/(1+diff*1.22233738403*tau)     None
# l_4_amplitude    0.9756     -inf      inf     None    False     None     None
# l_4_center     -0.0005717     -inf      inf     None    False     None     None
# l_4_fwhm         0.2556     -inf      inf     None    False     None     None
# l_4_height         2.43     -inf      inf     None    False     None     None
# l_4_sigma        0.1294        0      inf     None    False 0.658211951447*diff*1.6210556384/(1+diff*1.6210556384*tau)     None
# l_5_amplitude    0.9761     -inf      inf     None    False     None     None
# l_5_center     -0.001786     -inf      inf     None    False     None     None
# l_5_fwhm         0.3046     -inf      inf     None    False     None     None
# l_5_height         2.04     -inf      inf     None    False     None     None
# l_5_sigma        0.1531        0      inf     None    False 0.658211951447*diff*2.0282483529/(1+diff*2.0282483529*tau)     None
# l_6_amplitude    0.9751     -inf      inf     None    False     None     None
# l_6_center     -0.002642     -inf      inf     None    False     None     None
# l_6_fwhm         0.3534     -inf      inf     None    False     None     None
# l_6_height        1.757     -inf      inf     None    False     None     None
# l_6_sigma        0.1737        0      inf     None    False 0.658211951447*diff*2.42255219686/(1+diff*2.42255219686*tau)     None
# l_7_amplitude    0.9756     -inf      inf     None    False     None     None
# l_7_center     -0.002338     -inf      inf     None    False     None     None
# l_7_fwhm         0.3864     -inf      inf     None    False     None     None
# l_7_height        1.607     -inf      inf     None    False     None     None
# l_7_sigma        0.1909        0      inf     None    False 0.658211951447*diff*2.78316729758/(1+diff*2.78316729758*tau)     None
# l_8_amplitude    0.9731     -inf      inf     None    False     None     None
# l_8_center     -0.001824     -inf      inf     None    False     None     None
# l_8_fwhm         0.4175     -inf      inf     None    False     None     None
# l_8_height        1.484     -inf      inf     None    False     None     None
# l_8_sigma        0.2044        0      inf     None    False 0.658211951447*diff*3.09135604459/(1+diff*3.09135604459*tau)     None
# l_9_amplitude     0.974     -inf      inf     None    False     None     None
# l_9_center     -0.004211     -inf      inf     None    False     None     None
# l_9_fwhm         0.4153     -inf      inf     None    False     None     None
# l_9_height        1.493     -inf      inf     None    False     None     None
# l_9_sigma        0.2142        0      inf     None    False 0.658211951447*diff*3.33096909987/(1+diff*3.33096909987*tau)     None
# r_0_amplitude         1     -inf      inf     None    False     None     None
# r_0_center            0     -inf      inf     None    False     None     None
# r_1_amplitude         1     -inf      inf     None    False     None     None
# r_1_center            0     -inf      inf     None    False     None     None
# r_2_amplitude         1     -inf      inf     None    False     None     None
# r_2_center            0     -inf      inf     None    False     None     None
# r_3_amplitude         1     -inf      inf     None    False     None     None
# r_3_center            0     -inf      inf     None    False     None     None
# r_4_amplitude         1     -inf      inf     None    False     None     None
# r_4_center            0     -inf      inf     None    False     None     None
# r_5_amplitude         1     -inf      inf     None    False     None     None
# r_5_center            0     -inf      inf     None    False     None     None
# r_6_amplitude         1     -inf      inf     None    False     None     None
# r_6_center            0     -inf      inf     None    False     None     None
# r_7_amplitude         1     -inf      inf     None    False     None     None
# r_7_center            0     -inf      inf     None    False     None     None
# r_8_amplitude         1     -inf      inf     None    False     None     None
# r_8_center            0     -inf      inf     None    False     None     None
# r_9_amplitude         1     -inf      inf     None    False     None     None
# r_9_center            0     -inf      inf     None    False     None     None
# tau               1.164        0      inf     None     True     None     None

# %% [markdown]
# (<a href='#Table of Contents'>Top</a>)<a id='sim_fit_carryout'></a><h3>Carry out the Simultaneous Fit</h3>

# %%
def residuals(params):
    r"""Difference between model and experiment, weighted by the experimental error

    Parameters
    ----------
    params : lmfit.Parameters
        Parameters for the global model

    Returns
    -------
    numpy.ndarray
        1D array of residuals for the global model
    """
    l_residuals = list()
    for i in range(n_spectra):
        x = fr['x']  # fitting range of energies
        y = fr['y'][i]  # associated experimental intensities
        e = fr['e'][i]  # associated experimental errors
        model_evaluation = l_model[i].eval(x=x, params=params)
        l_residuals.append((model_evaluation - y) / e)
    return np.concatenate(l_residuals)

# Minimizer object using the parameter set for all models and the
# function to calculate all the residuals.
minimizer = lmfit.Minimizer(residuals, g_params)
g_fit = minimizer.minimize()
# Out:
# TypeError
#    <_ast.Module object at 0x7f93b92a21d0>
# unsupported operand type(s) for *: 'float' and 'function'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-22b99b57480f> in <module>()
#      24 # function to calculate all the residuals.
#      25 minimizer = lmfit.Minimizer(residuals, g_params)
# ---> 26 g_fit = minimizer.minimize()
#
# /SNS/users/jbq/conda/miniconda2/lib/python2.7/site-packages/lmfit/minimizer.pyc in minimize(self, method, params, **kws)
#    1636                         val.lower().startswith(user_method)):
#    1637                     kwargs['method'] = val
# -> 1638         return function(**kwargs)
#    1639
#    1640
#
# /SNS/users/jbq/conda/miniconda2/lib/python2.7/site-packages/lmfit/minimizer.pyc in leastsq(self, params, **kws)
#    1268
#    1269         """
# -> 1270         result = self.prepare_fit(params=params)
#    1271         result.method = 'leastsq'
#    1272         variables = result.init_vals
#
# /SNS/users/jbq/conda/miniconda2/lib/python2.7/site-packages/lmfit/minimizer.pyc in prepare_fit(self, params)
#     604             self.params = params
#     605         if isinstance(self.params, Parameters):
# --> 606             result.params = deepcopy(self.params)
#     607         elif isinstance(self.params, (list, tuple)):
#     608             result.params = Parameters()
#
# /SNS/users/jbq/conda/miniconda2/lib/python2.7/copy.pyc in deepcopy(x, memo, _nil)
#     172             copier = getattr(x, "__deepcopy__", None)
#     173             if copier:
# --> 174                 y = copier(memo)
#     175             else:
#     176                 reductor = dispatch_table.get(cls)
#
# /SNS/users/jbq/conda/miniconda2/lib/python2.7/site-packages/lmfit/parameter.pyc in __deepcopy__(self, memo)
#     133                 parameter_list.append(param)
#     134
# --> 135         _pars.add_many(*parameter_list)
#     136
#     137         return _pars
#
# /SNS/users/jbq/conda/miniconda2/lib/python2.7/site-packages/lmfit/parameter.pyc in add_many(self, *parlist)
#     373         for para in parlist:
#     374             if isinstance(para, Parameter):
# --> 375                 self.__setitem__(para.name, para)
#     376             else:
#     377                 param = Parameter(*para)
#
# /SNS/users/jbq/conda/miniconda2/lib/python2.7/site-packages/lmfit/parameter.pyc in __setitem__(self, key, par)
#     147         par.name = key
#     148         par._expr_eval = self._asteval
# --> 149         self._asteval.symtable[key] = par.value
#     150
#     151     def __add__(self, other):
#
# /SNS/users/jbq/conda/miniconda2/lib/python2.7/site-packages/lmfit/parameter.pyc in value(self)
#     802     def value(self):
#     803         """Return the numerical value of the Parameter, with bounds applied."""
# --> 804         return self._getval()
#     805
#     806     @value.setter
#
# /SNS/users/jbq/conda/miniconda2/lib/python2.7/site-packages/lmfit/parameter.pyc in _getval(self)
#     784                 if not self._delay_asteval:
#     785                     self.value = self._expr_eval(self._expr_ast)
# --> 786                     check_ast_errors(self._expr_eval)
#     787
#     788         if self._val is not None:
#
# /SNS/users/jbq/conda/miniconda2/lib/python2.7/site-packages/lmfit/parameter.pyc in check_ast_errors(expr_eval)
#      21     """Check for errors derived from asteval."""
#      22     if len(expr_eval.error) > 0:
# ---> 23         expr_eval.raise_exception(None)
#      24
#      25
#
# /SNS/users/jbq/conda/miniconda2/lib/python2.7/site-packages/asteval/asteval.pyc in raise_exception(self, node, exc, msg, expr, lineno)
#     246             except:
#     247                 exc = RuntimeError
# --> 248         raise exc(self.error_msg)
#     249
#     250     # main entry point for Ast node evaluation
#
# TypeError:  in expr='<_ast.Module object at 0x7f93b92a21d0>'
